# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

# %%
words = read_data(filename)
print('data type %s', type(words))
print('Data size %d' % len(words))
print ('some words:', words[:10])
# Out:
# some words: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
for kv in dictionary.items()[:10]:
    print(kv)
for kv in reverse_dictionary.items()[:10]:
    print(kv)
del words  # Hint to reduce memory.

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:9]])

for num_skips, skip_window in [(2, 1), (4, 2), (8,4)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'originated', 'as', 'term', 'of']
#
# with num_skips = 4 and skip_window = 4:
#     batch: ['term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['anarchism', 'originated', 'as', 'first', 'against', 'originated', 'first', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.807970
# Nearest to american: glow, overthrown, emerging, mists, hancock, eyelashes, rimfire, git,
# Nearest to a: mvp, pronged, solid, ngel, introspective, mendel, evagrius, vfl,
# Nearest to three: heywood, monophonic, amyraut, cursing, guatemalans, greenland, cetus, backslash,
# Nearest to will: utilized, shostakovich, disassembly, oneness, torch, adjacency, posterity, justly,
# Nearest to but: ckel, empties, estonians, gifford, dorn, appointed, merton, mumford,
# Nearest to zero: baa, ki, shrinks, indulgences, pass, goidelic, mutate, ast,
# Nearest to states: basal, samyaksam, autographed, historiographical, topmost, stain, beaufort, inferred,
# Nearest to an: refitted, analysed, cookery, carbine, lyricist, champs, affinities, professorship,
# Nearest to after: stoney, fang, andalusia, balto, jurist, persecute, eu, polynesia,
# Nearest to between: win, reneged, deserving, bram, tutankhamun, piacenza, haggard, kannada,
# Nearest to can: kane, aloysius, palais, similar, mankiewicz, suri, dalglish, recovery,
# Nearest to by: unsolicited, cats, gan, conceptualization, debilitating, nesmith, springing, catus,
# Nearest to they: injunctions, elections, file, mari, dynamo, granville, varieties, geneticists,
# Nearest to years: landmarks, scholar, watched, overridden, meanwhile, unbroken, botham, elkhart,
# Nearest to has: lichfield, lullaby, witwatersrand, theological, firstnode, senatus, aaliyah, eleusis,
# Nearest to this: herbicide, ruptured, subjected, served, ukrainians, finn, cheered, degenerated,
# Average loss at step 2000: 4.373883
# Average loss at step 4000: 3.864973
# Average loss at step 6000: 3.800315
# Average loss at step 8000: 3.689474
# Average loss at step 10000: 3.617079
# Nearest to american: eyelashes, weaves, and, amok, tleilaxu, westphalian, french, interrogation,
# Nearest to a: the, this, introspective, visas, lindh, dd, wide, apostate,
# Nearest to three: four, two, seven, six, five, eight, nine, zero,
# Nearest to will: would, can, could, torch, lonergan, must, shostakovich, utilized,
# Nearest to but: he, autostrada, might, precaution, hours, vip, gluing, psp,
# Nearest to zero: five, nine, eight, six, seven, four, three, two,
# Nearest to states: autographed, samyaksam, iole, stain, topmost, beaufort, entrances, ashkenazic,
# Nearest to an: excluded, cookery, coastline, the, rsc, analysed, bottlers, refitted,
# Nearest to after: eu, meteorological, stoney, during, as, jurist, harmonization, mentally,
# Nearest to between: with, cambodians, win, in, against, cooks, reneged, zamenhof,
# Nearest to can: may, would, could, kane, will, revoked, laterally, patton,
# Nearest to by: from, as, was, gan, emanations, be, on, cics,
# Nearest to they: he, there, it, we, granville, file, not, elections,
# Nearest to years: scholar, javier, watched, dilution, exam, mi, prix, landmarks,
# Nearest to has: had, was, is, have, halted, witwatersrand, greenblatt, beyer,
# Nearest to this: it, the, which, any, their, running, a, shamanism,
# Average loss at step 12000: 3.610510
# Average loss at step 14000: 3.572350
# Average loss at step 16000: 3.406037
# Average loss at step 18000: 3.458584
# Average loss at step 20000: 3.543547
# Nearest to american: french, tleilaxu, champaign, weaves, alyattes, british, lange, english,
# Nearest to a: any, this, australis, introspective, patroclus, mina, gm, ralf,
# Nearest to three: five, seven, six, two, four, eight, zero, one,
# Nearest to will: would, could, can, may, must, to, should, might,
# Nearest to but: however, which, and, when, that, will, pitaka, though,
# Nearest to zero: five, seven, six, three, nine, four, eight, two,
# Nearest to states: autographed, samyaksam, topmost, roping, stain, historiographical, sikhs, skynyrd,
# Nearest to an: cookery, excluded, rsc, the, bottlers, analysed, coastline, reginald,
# Nearest to after: during, when, loire, mentally, before, eu, dunkirk, by,
# Nearest to between: with, against, cambodians, cooks, zamenhof, reneged, in, eugenie,
# Nearest to can: may, could, would, will, must, should, revoked, laterally,
# Nearest to by: be, into, were, in, after, from, yudhoyono, lasker,
# Nearest to they: there, we, he, you, it, nimzowitsch, she, file,
# Nearest to years: javier, watched, mi, exam, dilution, scholar, necromancers, commuting,
# Nearest to has: had, have, is, was, halted, beyer, greenblatt, orbison,
# Nearest to this: which, it, the, any, a, theseus, pemberton, roms,
# Average loss at step 22000: 3.502947
# Average loss at step 24000: 3.489547
# Average loss at step 26000: 3.481335
# Average loss at step 28000: 3.484779
# Average loss at step 30000: 3.503049
# Nearest to american: french, english, tleilaxu, and, british, international, german, russian,
# Nearest to a: any, the, woodbridge, no, this, dd, ralf, patroclus,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to but: however, and, when, although, which, though, while, depatie,
# Nearest to zero: five, four, eight, seven, six, three, two, nine,
# Nearest to states: sikhs, historiographical, neverwinter, samyaksam, state, autographed, roping, nations,
# Nearest to an: cookery, rsc, excluded, augmentation, bottlers, refitted, rolf, halftime,
# Nearest to after: before, during, when, eu, dunkirk, from, loire, however,
# Nearest to between: with, against, in, cambodians, proportionality, on, reneged, eugenie,
# Nearest to can: may, could, would, will, must, should, might, to,
# Nearest to by: were, from, during, in, as, was, mckenna, transl,
# Nearest to they: there, we, he, it, you, she, not, who,
# Nearest to years: javier, mi, watched, mg, days, dilution, exam, uranhay,
# Nearest to has: had, have, is, was, halted, restart, beyer, greenblatt,
# Nearest to this: it, which, any, that, what, the, theseus, roms,
# Average loss at step 32000: 3.498451
# Average loss at step 34000: 3.497452
# Average loss at step 36000: 3.455650
# Average loss at step 38000: 3.301226
# Average loss at step 40000: 3.431008
# Nearest to american: french, russian, english, british, tleilaxu, australian, german, peltier,
# Nearest to a: any, the, another, or, forbes, dd, midway, introspective,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to will: would, can, may, must, could, should, might, cannot,
# Nearest to but: however, although, though, while, and, it, he, when,
# Nearest to zero: seven, five, six, eight, nine, three, four, two,
# Nearest to states: kingdom, neverwinter, autographed, nations, state, sikhs, roping, historiographical,
# Nearest to an: excluded, rsc, cookery, bottlers, augmentation, rolf, romanov, the,
# Nearest to after: before, during, dunkirk, when, pasted, from, eu, sheldon,
# Nearest to between: with, against, cambodians, into, within, proportionality, eugenie, vestiges,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to by: lasker, from, through, cics, suffice, surrealist, was, as,
# Nearest to they: we, there, he, you, it, she, these, nimzowitsch,
# Nearest to years: days, javier, times, dwt, time, troubadour, mi, watched,
# Nearest to has: had, have, was, is, since, greenblatt, halted, beyer,
# Nearest to this: which, it, the, that, cavers, some, he, pemberton,
# Average loss at step 42000: 3.435471
# Average loss at step 44000: 3.449924
# Average loss at step 46000: 3.450698
# Average loss at step 48000: 3.353197
# Average loss at step 50000: 3.384881
# Nearest to american: english, french, international, australian, russian, tleilaxu, champaign, italian,
# Nearest to a: the, any, patroclus, dd, introspective, insulation, another, observational,
# Nearest to three: four, six, seven, eight, five, two, nine, zero,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to but: however, although, while, though, and, depatie, when, renting,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to states: kingdom, nations, neverwinter, sikhs, autographed, roping, beaufort, state,
# Nearest to an: excluded, rsc, bottlers, cookery, augmentation, rolf, zurich, pham,
# Nearest to after: before, during, when, while, against, through, from, confirming,
# Nearest to between: against, with, within, about, in, proportionality, cambodians, eugenie,
# Nearest to can: could, may, would, will, must, should, might, cannot,
# Nearest to by: was, through, sonja, lumpur, under, patty, against, using,
# Nearest to they: he, we, there, you, she, it, nimzowitsch, these,
# Nearest to years: days, times, months, people, javier, year, time, decades,
# Nearest to has: had, have, is, was, since, greenblatt, husayn, solemn,
# Nearest to this: which, it, the, some, that, ccny, roms, he,
# Average loss at step 52000: 3.441239
# Average loss at step 54000: 3.431327
# Average loss at step 56000: 3.436128
# Average loss at step 58000: 3.394288
# Average loss at step 60000: 3.390702
# Nearest to american: international, russian, australian, english, french, european, german, champaign,
# Nearest to a: the, any, every, another, patroclus, ralf, cares, enix,
# Nearest to three: five, four, six, seven, two, eight, nine, zero,
# Nearest to will: would, could, may, must, can, should, might, does,
# Nearest to but: however, although, and, though, reductase, see, depatie, which,
# Nearest to zero: five, eight, four, six, seven, three, two, nine,
# Nearest to states: nations, kingdom, state, autographed, traditions, neverwinter, roping, us,
# Nearest to an: excluded, augmentation, rsc, rolf, respondent, cookery, bottlers, romanov,
# Nearest to after: before, during, when, while, despite, saw, although, however,
# Nearest to between: with, against, within, among, in, proportionality, concerning, eugenie,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to by: through, using, lumpur, under, cics, with, hempstead, surrealist,
# Nearest to they: we, there, he, you, she, nimzowitsch, it, these,
# Nearest to years: days, months, decades, times, year, people, weeks, javier,
# Nearest to has: had, have, is, was, greenblatt, closet, lukas, machined,
# Nearest to this: it, which, there, that, what, the, roms, some,
# Average loss at step 62000: 3.245644
# Average loss at step 64000: 3.261016
# Average loss at step 66000: 3.402870
# Average loss at step 68000: 3.392300
# Average loss at step 70000: 3.364317
# Nearest to american: international, english, australian, british, russian, european, french, champaign,
# Nearest to a: the, another, ralf, insulation, predominates, introspective, any, microprocessors,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to will: would, could, may, must, can, should, might, cannot,
# Nearest to but: however, although, and, though, troupes, which, see, that,
# Nearest to zero: five, four, eight, six, seven, three, two, nine,
# Nearest to states: nations, kingdom, state, roping, neverwinter, us, guinea, sikhs,
# Nearest to an: excluded, augmentation, rsc, cookery, rolf, simultaneity, eyebrows, bottlers,
# Nearest to after: before, during, when, while, despite, saw, for, kushan,
# Nearest to between: with, within, against, among, concerning, proportionality, from, through,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to by: using, through, in, cics, surrealist, with, multiplier, as,
# Nearest to they: we, he, there, you, she, it, nimzowitsch, these,
# Nearest to years: days, decades, months, weeks, times, year, dwt, centuries,
# Nearest to has: had, have, is, was, contains, since, machined, solemn,
# Nearest to this: which, it, the, that, some, another, what, there,
# Average loss at step 72000: 3.373273
# Average loss at step 74000: 3.343941
# Average loss at step 76000: 3.323945
# Average loss at step 78000: 3.356202
# Average loss at step 80000: 3.378856
# Nearest to american: international, australian, british, russian, french, english, german, european,
# Nearest to a: another, the, comically, ralf, chemicals, any, eerie, midway,
# Nearest to three: five, six, four, seven, eight, two, nine, zero,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to but: however, although, depatie, and, though, see, while, strikingly,
# Nearest to zero: five, seven, six, four, eight, three, nine, two,
# Nearest to states: kingdom, nations, state, us, sikhs, guinea, zee, roping,
# Nearest to an: excluded, rsc, cookery, augmentation, simultaneity, bookseller, halftime, rolf,
# Nearest to after: before, during, when, while, from, despite, saw, if,
# Nearest to between: within, among, with, against, concerning, through, over, into,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to by: through, from, surrealist, patty, without, shipwreck, when, under,
# Nearest to they: we, he, there, she, you, it, these, who,
# Nearest to years: days, months, decades, weeks, times, year, centuries, seasons,
# Nearest to has: had, have, is, was, since, having, contains, includes,
# Nearest to this: which, it, the, georgetown, there, what, that, some,
# Average loss at step 82000: 3.410964
# Average loss at step 84000: 3.411228
# Average loss at step 86000: 3.393293
# Average loss at step 88000: 3.356191
# Average loss at step 90000: 3.366520
# Nearest to american: british, english, australian, french, international, russian, italian, german,
# Nearest to a: the, any, patroclus, dd, hjalmar, sacked, eschatological, ralf,
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Nearest to will: would, must, could, can, should, may, might, cannot,
# Nearest to but: however, although, and, though, while, depatie, that, tanoana,
# Nearest to zero: five, six, seven, eight, four, three, two, nine,
# Nearest to states: kingdom, nations, us, state, roping, traditions, samyaksam, neverwinter,
# Nearest to an: rsc, excluded, augmentation, bottlers, respondent, cookery, racist, simultaneity,
# Nearest to after: before, during, while, when, despite, until, without, from,
# Nearest to between: within, with, against, among, concerning, through, into, over,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to by: through, without, under, unleashing, absentia, sonja, surrealist, lumpur,
# Nearest to they: we, he, there, you, she, it, eventually, nimzowitsch,
# Nearest to years: days, decades, months, weeks, centuries, year, minutes, times,
# Nearest to has: had, have, is, was, since, having, although, includes,
# Nearest to this: it, which, the, dicotyledons, some, brixton, caligula, another,
# Average loss at step 92000: 3.397147
# Average loss at step 94000: 3.253501
# Average loss at step 96000: 3.354713
# Average loss at step 98000: 3.241070
# Average loss at step 100000: 3.360978
# Nearest to american: british, international, australian, italian, french, knox, russian, canadian,
# Nearest to a: any, another, patroclus, the, wielded, cares, predominates, dd,
# Nearest to three: four, six, seven, five, two, eight, nine, zero,
# Nearest to will: would, must, can, could, should, may, might, cannot,
# Nearest to but: however, although, and, though, which, depatie, while, appear,
# Nearest to zero: five, four, seven, eight, six, two, three, nine,
# Nearest to states: kingdom, nations, state, us, roping, neverwinter, traditions, guinea,
# Nearest to an: augmentation, excluded, rsc, cookery, pham, straus, cfo, rolf,
# Nearest to after: before, during, when, while, despite, without, at, from,
# Nearest to between: with, within, among, concerning, against, through, over, into,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to by: without, through, using, including, nasal, under, surrealist, conjunct,
# Nearest to they: we, there, he, you, she, it, nimzowitsch, not,
# Nearest to years: days, months, decades, weeks, centuries, year, times, minutes,
# Nearest to has: had, have, is, was, since, having, closet, reformulation,
# Nearest to this: it, which, another, brixton, caligula, what, that, he,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# CBOW mod

# %%
#Pre work: read data into a list and build data set
words = read_data(filename)
data, count, dictionary, reverse_dictionary = build_dataset(words)
'''print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
for kv in dictionary.items()[:10]:
    print(kv)
for kv in reverse_dictionary.items()[:10]:
    print(kv)'''
del words  # Hint to reduce memory.

# %%
#func to generate training dataset for cbow mod
data_index = 0

def cbow_generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:9]])

for num_skips, skip_window in [(2, 1), (4, 2), (8,4)]:
    data_index = 0
    batch, labels = cbow_generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['term', 'anarchism', 'a', 'originated', 'term', 'of', 'as', 'originated']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#
# with num_skips = 8 and skip_window = 4:
#     batch: ['as', 'a', 'of', 'first', 'originated', 'abuse', 'anarchism', 'used']
#     labels: ['term', 'term', 'term', 'term', 'term', 'term', 'term', 'term']

# %% [markdown]
# Train a cbow mod

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
data_index = 0

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = cbow_generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.226397
# Nearest to there: wd, faceted, hieronymus, quotas, fasttrack, discourses, sidekick, developed,
# Nearest to will: petrified, ceramic, imagines, menachem, destabilization, asdb, gus, fg,
# Nearest to may: etymological, vinge, dworkin, highness, monos, yogi, fao, lagged,
# Nearest to but: selectable, bodhisattva, outperform, weekly, macintoshes, neburg, hbf, hammerstein,
# Nearest to who: uttar, morrow, incestuous, interest, tithes, insertions, wail, reality,
# Nearest to into: disambiguation, unimpressed, io, uu, tawhid, ways, embodying, kriegsmarine,
# Nearest to would: pashtun, minimise, conversion, bridal, believers, jewish, coded, metals,
# Nearest to is: falun, librettist, disdained, spiritualist, gerda, joanie, jagie, hawaii,
# Nearest to on: hestia, recognising, kurtz, coagulation, puritans, remixes, loach, stopper,
# Nearest to his: stays, reparations, womanhood, hodges, spoofs, investing, radiohead, navarre,
# Nearest to its: prevails, barnstorming, guillaume, vulgaris, mideast, eternal, reddish, fostering,
# Nearest to all: psychedelic, hymenoptera, occupations, memoirs, locomotives, mkultra, roc, hysteresis,
# Nearest to in: objectors, horses, ffg, discovery, vats, hen, decolonization, pattern,
# Nearest to also: genomes, calamine, portland, o, marlborough, rojcewicz, arkansas, commitments,
# Nearest to than: dtds, boito, ganglion, biomedical, pillow, replay, month, prospered,
# Nearest to that: burkina, plumb, bauhaus, casing, pentatonic, hillbilly, paula, cowdery,
# Average loss at step 2000: 4.363387
# Average loss at step 4000: 3.868029
# Average loss at step 6000: 3.790022
# Average loss at step 8000: 3.683927
# Average loss at step 10000: 3.615035
# Nearest to there: it, they, also, he, magnificat, sometimes, who, flaccus,
# Nearest to will: may, should, would, menachem, imagines, asdb, tutte, can,
# Nearest to may: will, can, etymological, would, ouagadougou, must, unsigned, lagged,
# Nearest to but: lobby, partita, horses, neburg, selectable, hashimoto, inundated, lifeboats,
# Nearest to who: he, uttar, they, maloney, there, batman, which, mannerheim,
# Nearest to into: disambiguation, keating, contribute, from, io, servlet, equinoctial, langue,
# Nearest to would: can, could, may, will, must, believers, announcements, to,
# Nearest to is: was, are, has, be, recourse, by, unleashing, describes,
# Nearest to on: in, at, from, recognising, rambling, of, chlamydia, holman,
# Nearest to his: their, its, her, s, the, revolutionaries, ashton, tombaugh,
# Nearest to its: his, the, their, neoplatonist, prevails, vulgaris, slaughtered, vico,
# Nearest to all: plowing, roc, valid, intron, dropouts, memoirs, den, those,
# Nearest to in: on, of, at, after, for, from, uncivilized, obey,
# Nearest to also: now, there, which, sometimes, often, who, nonlinear, mujahidin,
# Nearest to than: lasting, pillow, jedwabne, much, duchies, month, secunda, megawati,
# Nearest to that: which, it, this, burkina, where, bauhaus, chissano, arcas,
# Average loss at step 12000: 3.601196
# Average loss at step 14000: 3.569194
# Average loss at step 16000: 3.409901
# Average loss at step 18000: 3.458634
# Average loss at step 20000: 3.536107
# Nearest to there: it, they, he, magnificat, also, we, screwtape, which,
# Nearest to will: would, may, can, should, cannot, could, to, must,
# Nearest to may: can, would, will, must, might, could, should, ouagadougou,
# Nearest to but: however, and, if, which, is, lesions, carries, are,
# Nearest to who: he, which, they, batman, completeness, she, hack, uttar,
# Nearest to into: from, by, contribute, equinoctial, disambiguation, keating, pleads, depraved,
# Nearest to would: can, may, could, will, must, might, should, to,
# Nearest to is: was, are, has, but, be, were, crossbar, exiting,
# Nearest to on: in, at, batteries, upon, recognising, ineffable, disrespectful, within,
# Nearest to his: their, her, its, my, the, revolutionaries, these, tombaugh,
# Nearest to its: their, his, the, neoplatonist, prevails, communications, her, vico,
# Nearest to all: many, those, these, plowing, several, some, concerned, meadow,
# Nearest to in: at, on, with, from, by, during, for, of,
# Nearest to also: now, which, not, there, often, sometimes, ragged, usually,
# Nearest to than: or, lasting, much, pillow, raptor, drusus, megawati, pikemen,
# Nearest to that: which, however, marco, this, subpixels, burkina, what, plumb,
# Average loss at step 22000: 3.504675
# Average loss at step 24000: 3.494428
# Average loss at step 26000: 3.477301
# Average loss at step 28000: 3.481035
# Average loss at step 30000: 3.502608
# Nearest to there: they, it, we, he, magnificat, now, still, often,
# Nearest to will: would, can, may, should, could, cannot, must, might,
# Nearest to may: can, would, will, must, could, might, should, ouagadougou,
# Nearest to but: however, if, though, although, and, when, which, or,
# Nearest to who: he, they, which, she, never, uttar, and, now,
# Nearest to into: from, under, through, equinoctial, contribute, over, down, depraved,
# Nearest to would: will, could, can, may, must, might, should, to,
# Nearest to is: was, has, are, does, while, recourse, if, este,
# Nearest to on: in, upon, at, from, through, within, ferenc, around,
# Nearest to his: their, her, its, my, the, s, ashton, tombaugh,
# Nearest to its: their, the, his, prevails, her, whose, some, neoplatonist,
# Nearest to all: both, these, various, some, those, several, meadow, ashcroft,
# Nearest to in: on, at, of, under, and, by, from, within,
# Nearest to also: now, often, sometimes, which, still, astatine, predominance, usually,
# Nearest to than: much, or, messagepad, zapatista, pikemen, penalized, lasting, drusus,
# Nearest to that: which, what, however, this, arcas, bauhaus, vertebrae, where,
# Average loss at step 32000: 3.499109
# Average loss at step 34000: 3.500129
# Average loss at step 36000: 3.454320
# Average loss at step 38000: 3.303217
# Average loss at step 40000: 3.423312
# Nearest to there: it, they, he, now, we, she, usually, still,
# Nearest to will: would, can, may, could, should, must, cannot, might,
# Nearest to may: can, will, would, could, must, should, might, cannot,
# Nearest to but: however, and, although, it, did, while, though, which,
# Nearest to who: he, which, she, they, often, we, already, farnsworth,
# Nearest to into: from, through, insider, equinoctial, slow, ways, depraved, fledged,
# Nearest to would: will, could, can, may, must, might, should, did,
# Nearest to is: was, has, are, indy, unfold, while, does, analytic,
# Nearest to on: upon, at, foxes, in, filings, disrespectful, suspensions, during,
# Nearest to his: their, her, its, my, the, s, nihon, hologram,
# Nearest to its: their, his, her, the, vico, provisionally, ridgway, decode,
# Nearest to all: both, these, various, those, each, several, gonna, ashcroft,
# Nearest to in: during, of, on, rupees, and, thirst, for, between,
# Nearest to also: often, now, which, usually, sometimes, still, easily, it,
# Nearest to than: or, much, zapatista, penalized, hijacker, messagepad, raptor, secunda,
# Nearest to that: which, what, this, where, marco, vertebrae, however, beaconsfield,
# Average loss at step 42000: 3.434002
# Average loss at step 44000: 3.455688
# Average loss at step 46000: 3.454427
# Average loss at step 48000: 3.353837
# Average loss at step 50000: 3.384401
# Nearest to there: they, it, he, now, we, she, often, usually,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to may: can, would, will, must, could, should, might, cannot,
# Nearest to but: however, although, though, when, and, while, since, ecoregions,
# Nearest to who: he, which, she, they, farnsworth, never, now, already,
# Nearest to into: through, from, over, townshend, after, repelling, off, ways,
# Nearest to would: will, could, can, may, must, might, should, did,
# Nearest to is: was, has, are, loyalist, be, becomes, were, exclaimed,
# Nearest to on: upon, in, against, through, filings, disrespectful, within, during,
# Nearest to his: their, her, its, my, the, your, revolutionaries, cdg,
# Nearest to its: their, his, the, her, your, vico, patrol, whose,
# Nearest to all: both, gonna, various, some, every, wenceslaus, these, each,
# Nearest to in: during, of, from, within, on, under, and, at,
# Nearest to also: which, now, still, often, usually, sometimes, easily, navarro,
# Nearest to than: much, or, zapatista, penalized, ran, raptor, revolvers, pikemen,
# Nearest to that: which, however, where, what, vertebrae, arcas, this, hovered,
# Average loss at step 52000: 3.441117
# Average loss at step 54000: 3.422630
# Average loss at step 56000: 3.437212
# Average loss at step 58000: 3.396135
# Average loss at step 60000: 3.391624
# Nearest to there: they, it, now, he, we, she, this, usually,
# Nearest to will: would, could, may, can, must, should, cannot, might,
# Nearest to may: can, would, will, must, could, should, might, cannot,
# Nearest to but: however, and, although, though, or, foreigner, yet, while,
# Nearest to who: he, which, now, farnsworth, never, she, already, they,
# Nearest to into: through, from, over, under, repelling, with, luminosity, depraved,
# Nearest to would: will, could, may, can, must, might, should, did,
# Nearest to is: was, has, are, becomes, does, analytic, although, loyalist,
# Nearest to on: upon, in, through, within, proterozoic, around, holman, poorest,
# Nearest to his: her, their, its, my, revolutionaries, your, the, whose,
# Nearest to its: their, his, her, the, your, vico, patrol, quartier,
# Nearest to all: both, various, some, many, those, these, rooting, unaltered,
# Nearest to in: within, during, near, on, at, of, among, since,
# Nearest to also: now, still, often, usually, sometimes, easily, astatine, subsequently,
# Nearest to than: much, penalized, zapatista, or, but, initiates, staccato, consultant,
# Nearest to that: which, what, however, this, arcas, where, but, there,
# Average loss at step 62000: 3.245281
# Average loss at step 64000: 3.255642
# Average loss at step 66000: 3.403618
# Average loss at step 68000: 3.396461
# Average loss at step 70000: 3.360230
# Nearest to there: they, it, we, now, he, usually, she, still,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to but: however, although, though, and, see, foreigner, while, that,
# Nearest to who: he, which, never, farnsworth, she, gallic, they, already,
# Nearest to into: from, through, under, across, repelling, clp, townshend, in,
# Nearest to would: will, could, may, can, must, might, should, cannot,
# Nearest to is: was, has, are, be, although, does, contains, becomes,
# Nearest to on: upon, through, within, in, holman, wheelchair, around, undergraduate,
# Nearest to his: her, their, my, its, your, nihon, whose, revolutionaries,
# Nearest to its: their, his, her, the, your, vico, whose, estas,
# Nearest to all: some, both, various, many, rooting, every, several, these,
# Nearest to in: within, on, during, at, for, from, until, interconnects,
# Nearest to also: now, often, still, which, sometimes, usually, easily, subsequently,
# Nearest to than: much, or, staccato, penalized, consultant, zapatista, raptor, scuderia,
# Nearest to that: which, however, what, arcas, but, this, where, bauhaus,
# Average loss at step 72000: 3.372596
# Average loss at step 74000: 3.349798
# Average loss at step 76000: 3.311124
# Average loss at step 78000: 3.355862
# Average loss at step 80000: 3.377510
# Nearest to there: it, they, we, he, now, usually, she, still,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to may: can, would, could, will, must, might, should, cannot,
# Nearest to but: however, although, while, see, and, though, which, or,
# Nearest to who: he, she, never, which, they, already, farnsworth, originally,
# Nearest to into: through, from, slow, off, pleads, across, within, repelling,
# Nearest to would: could, will, may, can, must, might, should, did,
# Nearest to is: was, has, are, becomes, became, involves, be, although,
# Nearest to on: upon, through, in, at, holman, loach, within, against,
# Nearest to his: her, their, my, its, your, our, nihon, the,
# Nearest to its: their, his, her, your, the, whose, vico, estas,
# Nearest to all: both, various, each, many, rooting, gaetano, some, several,
# Nearest to in: within, during, until, since, on, at, around, throughout,
# Nearest to also: often, now, still, sometimes, actually, easily, which, usually,
# Nearest to than: much, or, penalized, while, staccato, raptor, foreigner, consultant,
# Nearest to that: which, however, where, what, shamans, this, arcas, vertebrae,
# Average loss at step 82000: 3.408573
# Average loss at step 84000: 3.409968
# Average loss at step 86000: 3.384529
# Average loss at step 88000: 3.349999
# Average loss at step 90000: 3.364855
# Nearest to there: it, they, now, we, he, she, still, generally,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to may: can, could, would, must, will, should, might, cannot,
# Nearest to but: however, although, and, though, while, see, which, since,
# Nearest to who: he, she, which, often, now, never, farnsworth, originally,
# Nearest to into: through, from, slow, clp, across, under, within, off,
# Nearest to would: could, will, can, might, may, must, should, did,
# Nearest to is: was, has, are, becomes, be, makes, although, does,
# Nearest to on: upon, at, through, foxes, under, in, against, amati,
# Nearest to his: her, their, its, my, our, your, nihon, the,
# Nearest to its: their, his, her, your, the, whose, estas, vico,
# Nearest to all: both, various, many, some, several, gaetano, each, every,
# Nearest to in: within, during, under, near, at, of, around, until,
# Nearest to also: now, often, still, actually, usually, which, sometimes, easily,
# Nearest to than: much, consultant, penalized, staccato, raptor, require, or, became,
# Nearest to that: which, what, however, where, chissano, bw, arcas, vertebrae,
# Average loss at step 92000: 3.401150
# Average loss at step 94000: 3.253276
# Average loss at step 96000: 3.357670
# Average loss at step 98000: 3.243988
# Average loss at step 100000: 3.355372
# Nearest to there: they, it, he, we, now, she, generally, usually,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to may: can, could, must, should, would, will, might, cannot,
# Nearest to but: however, although, and, though, while, which, when, soci,
# Nearest to who: he, never, she, which, farnsworth, now, userbase, already,
# Nearest to into: through, from, across, slow, clp, off, pleads, within,
# Nearest to would: will, could, can, might, may, must, should, did,
# Nearest to is: was, has, became, does, are, makes, be, had,
# Nearest to on: upon, through, within, at, in, holman, against, inside,
# Nearest to his: her, their, my, its, your, our, s, the,
# Nearest to its: their, his, your, the, her, whose, vico, estas,
# Nearest to all: both, various, many, every, these, some, several, those,
# Nearest to in: within, during, until, throughout, under, on, from, at,
# Nearest to also: now, actually, still, sometimes, often, which, usually, never,
# Nearest to than: or, require, much, consultant, and, chateau, penalized, staccato,
# Nearest to that: which, what, however, where, bauhaus, mayhew, plumb, demonstration,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
