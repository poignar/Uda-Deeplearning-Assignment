# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

# %%
words = read_data(filename)
print('data type %s', type(words))
print('Data size %d' % len(words))
print ('some words:', words[:10])
# Out:
# some words: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
for kv in dictionary.items()[:10]:
    print(kv)
for kv in reverse_dictionary.items()[:10]:
    print(kv)
del words  # Hint to reduce memory.

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:9]])

for num_skips, skip_window in [(2, 1), (4, 2), (8,4)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'originated', 'as', 'term', 'of']
#
# with num_skips = 4 and skip_window = 4:
#     batch: ['term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['anarchism', 'originated', 'as', 'first', 'against', 'originated', 'first', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.807970
# Nearest to american: glow, overthrown, emerging, mists, hancock, eyelashes, rimfire, git,
# Nearest to a: mvp, pronged, solid, ngel, introspective, mendel, evagrius, vfl,
# Nearest to three: heywood, monophonic, amyraut, cursing, guatemalans, greenland, cetus, backslash,
# Nearest to will: utilized, shostakovich, disassembly, oneness, torch, adjacency, posterity, justly,
# Nearest to but: ckel, empties, estonians, gifford, dorn, appointed, merton, mumford,
# Nearest to zero: baa, ki, shrinks, indulgences, pass, goidelic, mutate, ast,
# Nearest to states: basal, samyaksam, autographed, historiographical, topmost, stain, beaufort, inferred,
# Nearest to an: refitted, analysed, cookery, carbine, lyricist, champs, affinities, professorship,
# Nearest to after: stoney, fang, andalusia, balto, jurist, persecute, eu, polynesia,
# Nearest to between: win, reneged, deserving, bram, tutankhamun, piacenza, haggard, kannada,
# Nearest to can: kane, aloysius, palais, similar, mankiewicz, suri, dalglish, recovery,
# Nearest to by: unsolicited, cats, gan, conceptualization, debilitating, nesmith, springing, catus,
# Nearest to they: injunctions, elections, file, mari, dynamo, granville, varieties, geneticists,
# Nearest to years: landmarks, scholar, watched, overridden, meanwhile, unbroken, botham, elkhart,
# Nearest to has: lichfield, lullaby, witwatersrand, theological, firstnode, senatus, aaliyah, eleusis,
# Nearest to this: herbicide, ruptured, subjected, served, ukrainians, finn, cheered, degenerated,
# Average loss at step 2000: 4.373883
# Average loss at step 4000: 3.864973
# Average loss at step 6000: 3.800315
# Average loss at step 8000: 3.689474
# Average loss at step 10000: 3.617079
# Nearest to american: eyelashes, weaves, and, amok, tleilaxu, westphalian, french, interrogation,
# Nearest to a: the, this, introspective, visas, lindh, dd, wide, apostate,
# Nearest to three: four, two, seven, six, five, eight, nine, zero,
# Nearest to will: would, can, could, torch, lonergan, must, shostakovich, utilized,
# Nearest to but: he, autostrada, might, precaution, hours, vip, gluing, psp,
# Nearest to zero: five, nine, eight, six, seven, four, three, two,
# Nearest to states: autographed, samyaksam, iole, stain, topmost, beaufort, entrances, ashkenazic,
# Nearest to an: excluded, cookery, coastline, the, rsc, analysed, bottlers, refitted,
# Nearest to after: eu, meteorological, stoney, during, as, jurist, harmonization, mentally,
# Nearest to between: with, cambodians, win, in, against, cooks, reneged, zamenhof,
# Nearest to can: may, would, could, kane, will, revoked, laterally, patton,
# Nearest to by: from, as, was, gan, emanations, be, on, cics,
# Nearest to they: he, there, it, we, granville, file, not, elections,
# Nearest to years: scholar, javier, watched, dilution, exam, mi, prix, landmarks,
# Nearest to has: had, was, is, have, halted, witwatersrand, greenblatt, beyer,
# Nearest to this: it, the, which, any, their, running, a, shamanism,
# Average loss at step 12000: 3.610510
# Average loss at step 14000: 3.572350
# Average loss at step 16000: 3.406037
# Average loss at step 18000: 3.458584
# Average loss at step 20000: 3.543547
# Nearest to american: french, tleilaxu, champaign, weaves, alyattes, british, lange, english,
# Nearest to a: any, this, australis, introspective, patroclus, mina, gm, ralf,
# Nearest to three: five, seven, six, two, four, eight, zero, one,
# Nearest to will: would, could, can, may, must, to, should, might,
# Nearest to but: however, which, and, when, that, will, pitaka, though,
# Nearest to zero: five, seven, six, three, nine, four, eight, two,
# Nearest to states: autographed, samyaksam, topmost, roping, stain, historiographical, sikhs, skynyrd,
# Nearest to an: cookery, excluded, rsc, the, bottlers, analysed, coastline, reginald,
# Nearest to after: during, when, loire, mentally, before, eu, dunkirk, by,
# Nearest to between: with, against, cambodians, cooks, zamenhof, reneged, in, eugenie,
# Nearest to can: may, could, would, will, must, should, revoked, laterally,
# Nearest to by: be, into, were, in, after, from, yudhoyono, lasker,
# Nearest to they: there, we, he, you, it, nimzowitsch, she, file,
# Nearest to years: javier, watched, mi, exam, dilution, scholar, necromancers, commuting,
# Nearest to has: had, have, is, was, halted, beyer, greenblatt, orbison,
# Nearest to this: which, it, the, any, a, theseus, pemberton, roms,
# Average loss at step 22000: 3.502947
# Average loss at step 24000: 3.489547
# Average loss at step 26000: 3.481335
# Average loss at step 28000: 3.484779
# Average loss at step 30000: 3.503049
# Nearest to american: french, english, tleilaxu, and, british, international, german, russian,
# Nearest to a: any, the, woodbridge, no, this, dd, ralf, patroclus,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to but: however, and, when, although, which, though, while, depatie,
# Nearest to zero: five, four, eight, seven, six, three, two, nine,
# Nearest to states: sikhs, historiographical, neverwinter, samyaksam, state, autographed, roping, nations,
# Nearest to an: cookery, rsc, excluded, augmentation, bottlers, refitted, rolf, halftime,
# Nearest to after: before, during, when, eu, dunkirk, from, loire, however,
# Nearest to between: with, against, in, cambodians, proportionality, on, reneged, eugenie,
# Nearest to can: may, could, would, will, must, should, might, to,
# Nearest to by: were, from, during, in, as, was, mckenna, transl,
# Nearest to they: there, we, he, it, you, she, not, who,
# Nearest to years: javier, mi, watched, mg, days, dilution, exam, uranhay,
# Nearest to has: had, have, is, was, halted, restart, beyer, greenblatt,
# Nearest to this: it, which, any, that, what, the, theseus, roms,
# Average loss at step 32000: 3.498451
# Average loss at step 34000: 3.497452
# Average loss at step 36000: 3.455650
# Average loss at step 38000: 3.301226
# Average loss at step 40000: 3.431008
# Nearest to american: french, russian, english, british, tleilaxu, australian, german, peltier,
# Nearest to a: any, the, another, or, forbes, dd, midway, introspective,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to will: would, can, may, must, could, should, might, cannot,
# Nearest to but: however, although, though, while, and, it, he, when,
# Nearest to zero: seven, five, six, eight, nine, three, four, two,
# Nearest to states: kingdom, neverwinter, autographed, nations, state, sikhs, roping, historiographical,
# Nearest to an: excluded, rsc, cookery, bottlers, augmentation, rolf, romanov, the,
# Nearest to after: before, during, dunkirk, when, pasted, from, eu, sheldon,
# Nearest to between: with, against, cambodians, into, within, proportionality, eugenie, vestiges,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to by: lasker, from, through, cics, suffice, surrealist, was, as,
# Nearest to they: we, there, he, you, it, she, these, nimzowitsch,
# Nearest to years: days, javier, times, dwt, time, troubadour, mi, watched,
# Nearest to has: had, have, was, is, since, greenblatt, halted, beyer,
# Nearest to this: which, it, the, that, cavers, some, he, pemberton,
# Average loss at step 42000: 3.435471
# Average loss at step 44000: 3.449924
# Average loss at step 46000: 3.450698
# Average loss at step 48000: 3.353197
# Average loss at step 50000: 3.384881
# Nearest to american: english, french, international, australian, russian, tleilaxu, champaign, italian,
# Nearest to a: the, any, patroclus, dd, introspective, insulation, another, observational,
# Nearest to three: four, six, seven, eight, five, two, nine, zero,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to but: however, although, while, though, and, depatie, when, renting,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to states: kingdom, nations, neverwinter, sikhs, autographed, roping, beaufort, state,
# Nearest to an: excluded, rsc, bottlers, cookery, augmentation, rolf, zurich, pham,
# Nearest to after: before, during, when, while, against, through, from, confirming,
# Nearest to between: against, with, within, about, in, proportionality, cambodians, eugenie,
# Nearest to can: could, may, would, will, must, should, might, cannot,
# Nearest to by: was, through, sonja, lumpur, under, patty, against, using,
# Nearest to they: he, we, there, you, she, it, nimzowitsch, these,
# Nearest to years: days, times, months, people, javier, year, time, decades,
# Nearest to has: had, have, is, was, since, greenblatt, husayn, solemn,
# Nearest to this: which, it, the, some, that, ccny, roms, he,
# Average loss at step 52000: 3.441239
# Average loss at step 54000: 3.431327
# Average loss at step 56000: 3.436128
# Average loss at step 58000: 3.394288
# Average loss at step 60000: 3.390702
# Nearest to american: international, russian, australian, english, french, european, german, champaign,
# Nearest to a: the, any, every, another, patroclus, ralf, cares, enix,
# Nearest to three: five, four, six, seven, two, eight, nine, zero,
# Nearest to will: would, could, may, must, can, should, might, does,
# Nearest to but: however, although, and, though, reductase, see, depatie, which,
# Nearest to zero: five, eight, four, six, seven, three, two, nine,
# Nearest to states: nations, kingdom, state, autographed, traditions, neverwinter, roping, us,
# Nearest to an: excluded, augmentation, rsc, rolf, respondent, cookery, bottlers, romanov,
# Nearest to after: before, during, when, while, despite, saw, although, however,
# Nearest to between: with, against, within, among, in, proportionality, concerning, eugenie,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to by: through, using, lumpur, under, cics, with, hempstead, surrealist,
# Nearest to they: we, there, he, you, she, nimzowitsch, it, these,
# Nearest to years: days, months, decades, times, year, people, weeks, javier,
# Nearest to has: had, have, is, was, greenblatt, closet, lukas, machined,
# Nearest to this: it, which, there, that, what, the, roms, some,
# Average loss at step 62000: 3.245644
# Average loss at step 64000: 3.261016
# Average loss at step 66000: 3.402870
# Average loss at step 68000: 3.392300
# Average loss at step 70000: 3.364317
# Nearest to american: international, english, australian, british, russian, european, french, champaign,
# Nearest to a: the, another, ralf, insulation, predominates, introspective, any, microprocessors,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to will: would, could, may, must, can, should, might, cannot,
# Nearest to but: however, although, and, though, troupes, which, see, that,
# Nearest to zero: five, four, eight, six, seven, three, two, nine,
# Nearest to states: nations, kingdom, state, roping, neverwinter, us, guinea, sikhs,
# Nearest to an: excluded, augmentation, rsc, cookery, rolf, simultaneity, eyebrows, bottlers,
# Nearest to after: before, during, when, while, despite, saw, for, kushan,
# Nearest to between: with, within, against, among, concerning, proportionality, from, through,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to by: using, through, in, cics, surrealist, with, multiplier, as,
# Nearest to they: we, he, there, you, she, it, nimzowitsch, these,
# Nearest to years: days, decades, months, weeks, times, year, dwt, centuries,
# Nearest to has: had, have, is, was, contains, since, machined, solemn,
# Nearest to this: which, it, the, that, some, another, what, there,
# Average loss at step 72000: 3.373273
# Average loss at step 74000: 3.343941
# Average loss at step 76000: 3.323945
# Average loss at step 78000: 3.356202
# Average loss at step 80000: 3.378856
# Nearest to american: international, australian, british, russian, french, english, german, european,
# Nearest to a: another, the, comically, ralf, chemicals, any, eerie, midway,
# Nearest to three: five, six, four, seven, eight, two, nine, zero,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to but: however, although, depatie, and, though, see, while, strikingly,
# Nearest to zero: five, seven, six, four, eight, three, nine, two,
# Nearest to states: kingdom, nations, state, us, sikhs, guinea, zee, roping,
# Nearest to an: excluded, rsc, cookery, augmentation, simultaneity, bookseller, halftime, rolf,
# Nearest to after: before, during, when, while, from, despite, saw, if,
# Nearest to between: within, among, with, against, concerning, through, over, into,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to by: through, from, surrealist, patty, without, shipwreck, when, under,
# Nearest to they: we, he, there, she, you, it, these, who,
# Nearest to years: days, months, decades, weeks, times, year, centuries, seasons,
# Nearest to has: had, have, is, was, since, having, contains, includes,
# Nearest to this: which, it, the, georgetown, there, what, that, some,
# Average loss at step 82000: 3.410964
# Average loss at step 84000: 3.411228
# Average loss at step 86000: 3.393293
# Average loss at step 88000: 3.356191
# Average loss at step 90000: 3.366520
# Nearest to american: british, english, australian, french, international, russian, italian, german,
# Nearest to a: the, any, patroclus, dd, hjalmar, sacked, eschatological, ralf,
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Nearest to will: would, must, could, can, should, may, might, cannot,
# Nearest to but: however, although, and, though, while, depatie, that, tanoana,
# Nearest to zero: five, six, seven, eight, four, three, two, nine,
# Nearest to states: kingdom, nations, us, state, roping, traditions, samyaksam, neverwinter,
# Nearest to an: rsc, excluded, augmentation, bottlers, respondent, cookery, racist, simultaneity,
# Nearest to after: before, during, while, when, despite, until, without, from,
# Nearest to between: within, with, against, among, concerning, through, into, over,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to by: through, without, under, unleashing, absentia, sonja, surrealist, lumpur,
# Nearest to they: we, he, there, you, she, it, eventually, nimzowitsch,
# Nearest to years: days, decades, months, weeks, centuries, year, minutes, times,
# Nearest to has: had, have, is, was, since, having, although, includes,
# Nearest to this: it, which, the, dicotyledons, some, brixton, caligula, another,
# Average loss at step 92000: 3.397147
# Average loss at step 94000: 3.253501
# Average loss at step 96000: 3.354713
# Average loss at step 98000: 3.241070
# Average loss at step 100000: 3.360978
# Nearest to american: british, international, australian, italian, french, knox, russian, canadian,
# Nearest to a: any, another, patroclus, the, wielded, cares, predominates, dd,
# Nearest to three: four, six, seven, five, two, eight, nine, zero,
# Nearest to will: would, must, can, could, should, may, might, cannot,
# Nearest to but: however, although, and, though, which, depatie, while, appear,
# Nearest to zero: five, four, seven, eight, six, two, three, nine,
# Nearest to states: kingdom, nations, state, us, roping, neverwinter, traditions, guinea,
# Nearest to an: augmentation, excluded, rsc, cookery, pham, straus, cfo, rolf,
# Nearest to after: before, during, when, while, despite, without, at, from,
# Nearest to between: with, within, among, concerning, against, through, over, into,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to by: without, through, using, including, nasal, under, surrealist, conjunct,
# Nearest to they: we, there, he, you, she, it, nimzowitsch, not,
# Nearest to years: days, months, decades, weeks, centuries, year, times, minutes,
# Nearest to has: had, have, is, was, since, having, closet, reformulation,
# Nearest to this: it, which, another, brixton, caligula, what, that, he,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# CBOW mod

# %%
#Pre work: read data into a list and build data set
words = read_data(filename)
data, count, dictionary, reverse_dictionary = build_dataset(words)
'''print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
for kv in dictionary.items()[:10]:
    print(kv)
for kv in reverse_dictionary.items()[:10]:
    print(kv)'''
del words  # Hint to reduce memory.

# %%
#func to generate training dataset for cbow mod
data_index = 0

def cbow_generate_batch(batch_size, bag_window):
  assert batch_size % (2 * bag_window) == 0
  global data_index
  span = 2 * bag_window + 1
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list[bag_window]
    batch[i] = np.append(buffer_list[:bag_window], buffer_list[bag_window+1:])
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:10]])

for bag_window in [1, 2, 4]:
    data_index = 0
    batch, labels = cbow_generate_batch(batch_size=8, bag_window=bag_window)
    print('\nwith  bag_window = %d:' % (bag_window))
    print('    batch:',  [[reverse_dictionary[bj] for bj in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with  bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with  bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with  bag_window = 4:
#     batch: [['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used'], ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against'], ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early'], ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working'], ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class'], ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals'], ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including'], ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']]
#     labels: ['term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']

# %% [markdown]
# Train a cbow mod

# %%
batch_size = 128
embedding_size = 132 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * bag_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print('sizeof embed: ',np.shape(embed))
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# sizeof embed:  (128, 4, 132)

# %%
num_steps = 100001
data_index = 0

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = cbow_generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.073249
# Nearest to this: reformists, collected, imprints, jahan, joke, guernica, ladd, hundredth,
# Nearest to if: fantastic, blank, backtracking, compactness, generalised, unlimited, administrated, psychoanalyst,
# Nearest to all: rtp, arp, bioses, trading, gprs, tortoise, cubic, feedback,
# Nearest to at: resonating, emily, slurred, analysing, recalled, bua, arise, mesoamerica,
# Nearest to state: courting, hf, activism, endlessly, bigg, bombing, indoor, mentor,
# Nearest to of: cirrhosis, uncreated, hmas, ign, dobson, icmp, baldrick, teller,
# Nearest to up: talkies, suburbs, wanderings, millionaires, smith, disallow, inscriptions, benefitted,
# Nearest to that: infielders, bastions, daemons, wish, mercator, maxims, ovens, icp,
# Nearest to people: martov, berber, koichi, conceivable, regionally, incidence, electrocution, indulge,
# Nearest to see: probus, unbelief, proclaim, asterism, barb, making, lexicographic, osce,
# Nearest to use: select, bhp, vassal, congolese, albury, laments, afloat, multiplexing,
# Nearest to seven: ninja, hodge, jordan, starts, skaldic, originating, microfilm, linkage,
# Nearest to as: wolverine, pub, jets, cherished, vanes, host, sacked, subsystem,
# Nearest to been: reporter, coincidentally, expelling, primer, shrew, technological, evasive, fema,
# Nearest to had: goin, azure, enki, lumi, cambridgeshire, yama, melito, tends,
# Nearest to s: trivially, etymological, rebuked, sayings, playlists, quran, boadicea, mmo,
# Average loss at step 2000: 4.601524
# Average loss at step 4000: 3.941382
# Average loss at step 6000: 3.735114
# Average loss at step 8000: 3.532194
# Average loss at step 10000: 3.486426
# Nearest to this: it, which, the, an, solidify, its, dielectric, priestley,
# Nearest to if: circulates, psychoanalyst, fantastic, seminal, slovenian, lengthwise, commenting, forties,
# Nearest to all: many, gall, joanna, pyrite, other, klerk, transitive, vn,
# Nearest to at: in, virtualization, sophia, cesium, nger, jigs, isles, colombia,
# Nearest to state: unseen, solar, mmx, optical, potion, guinean, hallucination, abm,
# Nearest to of: for, aai, manet, siddha, s, swf, functionaries, cara,
# Nearest to up: disruptions, schengen, talkies, overcast, tumble, depending, netting, ww,
# Nearest to that: which, who, infielders, where, wolfram, when, also, peculiarities,
# Nearest to people: ofcom, those, herodotus, pani, firsts, sanctified, staple, wilfred,
# Nearest to see: dolly, probus, singin, omim, backwards, vih, teenager, fluoride,
# Nearest to use: vassal, male, anniversary, antiochian, alekhine, ctesiphon, youth, patterns,
# Nearest to seven: eight, nine, six, five, four, three, zero, hours,
# Nearest to as: injections, pekah, ably, when, seminar, deprecated, whedon, cow,
# Nearest to been: become, come, sophistication, fer, grinch, homosexuals, abrahamic, gayoom,
# Nearest to had: has, have, were, was, having, famed, alchemist, vitrification,
# Nearest to s: flensburg, pathogens, malory, clays, subgenius, knives, hoare, sess,
# Average loss at step 12000: 3.498519
# Average loss at step 14000: 3.449797
# Average loss at step 16000: 3.445909
# Average loss at step 18000: 3.405882
# Average loss at step 20000: 3.229968
# Nearest to this: that, it, which, sch, the, tribulations, another, convened,
# Nearest to if: when, though, where, although, however, boer, because, grievances,
# Nearest to all: many, these, some, certain, moraine, any, various, entirely,
# Nearest to at: virtualization, before, pessoa, over, since, frantic, hollandic, rial,
# Nearest to state: ccc, unseen, decoy, fsln, existing, government, seaside, official,
# Nearest to of: twa, against, since, alexandra, offensively, during, chung, while,
# Nearest to up: back, out, tumble, hizballah, try, disruptions, kill, iterate,
# Nearest to that: this, which, where, however, when, who, what, smokers,
# Nearest to people: those, men, others, them, learns, languages, scream, gokturks,
# Nearest to see: dolly, climatology, singin, ule, recharge, characterisation, robbie, stonehenge,
# Nearest to use: form, extreme, alekhine, mel, handlebars, fluctuations, electrocution, utensils,
# Nearest to seven: six, five, eight, three, zero, four, nine, two,
# Nearest to as: backstreet, deprecated, pentatonic, gana, suspend, markup, strategy, vogue,
# Nearest to been: become, fer, come, grinch, abrahamic, mei, kerosene, homosexuals,
# Nearest to had: has, have, having, were, was, famed, would, misleadingly,
# Nearest to s: his, mandola, septimania, your, toffler, decibels, xviii, halen,
# Average loss at step 22000: 3.376767
# Average loss at step 24000: 3.295754
# Average loss at step 26000: 3.259673
# Average loss at step 28000: 3.287970
# Average loss at step 30000: 3.238648
# Nearest to this: it, which, the, that, still, what, an, also,
# Nearest to if: when, though, where, that, syndicated, because, without, then,
# Nearest to all: many, some, any, certain, those, various, undocumented, moraine,
# Nearest to at: since, in, virtualization, sundays, zorro, crystallography, cite, intransitive,
# Nearest to state: existing, unseen, ccc, sheaf, government, governor, title, gottlieb,
# Nearest to of: in, during, including, for, within, among, before, dobson,
# Nearest to up: out, off, back, iterate, him, netting, universiti, tumble,
# Nearest to that: which, where, what, this, if, when, who, epa,
# Nearest to people: americans, them, men, those, groups, members, languages, uart,
# Nearest to see: but, includes, dolly, singin, climatology, wedded, advertiser, xxiv,
# Nearest to use: need, dumping, pcp, sense, pointwise, support, form, return,
# Nearest to seven: eight, nine, five, six, four, three, zero, one,
# Nearest to as: became, mime, inexpensively, pasiphae, relativist, ably, mutate, extravagance,
# Nearest to been: become, come, be, fer, remained, grosbeak, anaximander, evolved,
# Nearest to had: has, have, having, was, gave, could, replicator, hitchens,
# Nearest to s: his, her, rapture, thermonuclear, keystroke, delaunay, siculus, bahri,
# Average loss at step 32000: 3.024934
# Average loss at step 34000: 3.203380
# Average loss at step 36000: 3.209881
# Average loss at step 38000: 3.166636
# Average loss at step 40000: 3.160262
# Nearest to this: which, it, the, another, chaldea, any, a, what,
# Nearest to if: though, where, when, chobert, since, although, gif, because,
# Nearest to all: many, various, several, any, every, mandrake, miranda, always,
# Nearest to at: across, pessoa, after, intransitive, virtualization, over, near, during,
# Nearest to state: unseen, california, gatehouse, bulb, kryptonian, orwell, sheaf, bandage,
# Nearest to of: functionaries, twa, bankruptcies, during, in, mri, nicopolis, represents,
# Nearest to up: off, out, down, away, him, netting, back, quieter,
# Nearest to that: which, although, infielders, however, libri, where, but, capsules,
# Nearest to people: men, americans, them, apollon, women, children, those, members,
# Nearest to see: includes, but, dolly, roasted, called, climatology, robbie, contains,
# Nearest to use: form, sense, pcp, way, consist, because, hamilcar, develop,
# Nearest to seven: eight, six, five, four, nine, three, zero, approximating,
# Nearest to as: backstreet, spectacled, injections, miscellaneous, raja, summarize, hashimoto, munitions,
# Nearest to been: become, remained, fer, come, occurred, evolved, be, fallen,
# Nearest to had: has, have, having, could, can, was, gave, were,
# Nearest to s: equine, clinics, whose, his, sess, ghilzai, unassigned, hoare,
# Average loss at step 42000: 3.222971
# Average loss at step 44000: 3.151396
# Average loss at step 46000: 3.142993
# Average loss at step 48000: 3.063906
# Average loss at step 50000: 3.067252
# Nearest to this: which, it, what, an, another, the, spherically, izmir,
# Nearest to if: when, though, where, before, chobert, since, because, eek,
# Nearest to all: many, some, any, several, every, ise, various, blasphemous,
# Nearest to at: near, after, during, intransitive, when, from, wroc, before,
# Nearest to state: california, government, constructions, sheaf, unseen, marchers, bulb, supreme,
# Nearest to of: following, including, bronchitis, for, validate, after, while, polysaccharide,
# Nearest to up: off, out, him, back, netting, down, absurdum, together,
# Nearest to that: which, although, where, what, whom, however, because, why,
# Nearest to people: children, men, americans, players, them, women, those, individuals,
# Nearest to see: includes, known, include, called, climatology, dolly, allows, robbie,
# Nearest to use: consist, usage, used, pcp, treatment, exist, fuse, sense,
# Nearest to seven: eight, six, five, nine, three, four, zero, hams,
# Nearest to as: ably, backstreet, spectacled, overtake, filesystem, conquers, blica, homininae,
# Nearest to been: become, fer, remained, occurred, fallen, already, come, was,
# Nearest to had: has, have, having, was, gave, saw, holds, would,
# Nearest to s: isbn, his, whose, your, amy, valkyrie, ghilzai, gig,
# Average loss at step 52000: 3.103078
# Average loss at step 54000: 3.096471
# Average loss at step 56000: 2.933715
# Average loss at step 58000: 3.035352
# Average loss at step 60000: 3.056008
# Nearest to this: it, another, which, chaldea, alcindor, peikoff, what, the,
# Nearest to if: though, when, although, because, where, since, until, udf,
# Nearest to all: many, some, certain, both, various, several, those, every,
# Nearest to at: near, during, in, around, productivity, cite, on, pessoa,
# Nearest to state: alma, government, cdu, danzig, connexion, emanation, kryptonian, udf,
# Nearest to of: in, regarding, following, however, judi, include, twa, drava,
# Nearest to up: off, out, back, down, quieter, absurdum, brp, him,
# Nearest to that: which, however, where, what, although, because, pep, kennings,
# Nearest to people: americans, sellers, men, players, nations, tribes, those, students,
# Nearest to see: include, includes, but, known, called, robbie, saw, phillip,
# Nearest to use: consist, form, addition, allow, exist, efficiency, remain, screenwriters,
# Nearest to seven: eight, six, five, four, nine, three, zero, bc,
# Nearest to as: kore, backstreet, pommel, wahhabism, dora, autocephalous, shangri, lumpur,
# Nearest to been: become, fer, remained, fallen, occurred, come, evolved, grown,
# Nearest to had: has, have, having, was, gave, took, holds, were,
# Nearest to s: his, whose, her, ghilzai, your, est, isbn, hoare,
# Average loss at step 62000: 3.014188
# Average loss at step 64000: 2.923012
# Average loss at step 66000: 2.931482
# Average loss at step 68000: 2.980336
# Average loss at step 70000: 3.011190
# Nearest to this: another, it, which, what, chaldea, dipyramid, izmir, casualty,
# Nearest to if: when, though, where, since, because, although, before, therefore,
# Nearest to all: many, certain, both, several, various, quotient, every, some,
# Nearest to at: near, during, in, cvd, around, on, over, vs,
# Nearest to state: chrome, danzig, impetuous, cinema, detectors, udf, florida, government,
# Nearest to of: including, for, during, throughout, represents, dobson, gives, behind,
# Nearest to up: off, back, down, out, quieter, dime, netting, rollins,
# Nearest to that: which, where, what, who, although, whose, this, epa,
# Nearest to people: others, women, children, animals, men, americans, students, players,
# Nearest to see: includes, called, robbie, known, saw, include, unconsciously, provides,
# Nearest to use: consist, allow, cause, usage, practice, fuse, share, analyze,
# Nearest to seven: six, five, three, eight, four, two, zero, nine,
# Nearest to as: ment, backstreet, injections, universite, autocephalous, cale, spectacled, kenilworth,
# Nearest to been: become, remained, occurred, fer, be, appeared, fallen, grown,
# Nearest to had: has, have, having, were, was, wrote, showed, porsche,
# Nearest to s: his, whose, her, its, hoare, discrepancies, mayotte, electronegative,
# Average loss at step 72000: 2.947046
# Average loss at step 74000: 2.868957
# Average loss at step 76000: 3.004537
# Average loss at step 78000: 3.014847
# Average loss at step 80000: 2.848282
# Nearest to this: which, it, another, what, that, alcindor, itself, gravestone,
# Nearest to if: though, where, when, although, before, thus, because, however,
# Nearest to all: many, several, various, every, certain, any, some, both,
# Nearest to at: near, outside, during, towards, around, vs, intransitive, hol,
# Nearest to state: cinema, kingdom, butt, states, government, neuroscientists, overzealous, udf,
# Nearest to of: including, while, regarding, behind, atzma, within, following, throughout,
# Nearest to up: off, back, down, out, forward, together, brp, absurdum,
# Nearest to that: which, what, how, although, devolution, this, when, epa,
# Nearest to people: women, individuals, americans, person, children, men, students, residents,
# Nearest to see: but, include, climatology, includes, known, workmanship, wilde, roasted,
# Nearest to use: consist, cause, usage, form, help, course, allow, study,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to as: backstreet, mime, became, jaroslav, menai, concealment, universite, mouton,
# Nearest to been: become, occurred, fallen, fer, come, grown, remained, begun,
# Nearest to had: has, have, having, was, were, could, holds, gives,
# Nearest to s: whose, his, walras, wolsey, sis, leaving, blanco, halen,
# Average loss at step 82000: 2.943400
# Average loss at step 84000: 2.904759
# Average loss at step 86000: 2.922993
# Average loss at step 88000: 2.942735
# Average loss at step 90000: 2.828200
# Nearest to this: which, another, it, what, that, alcindor, a, the,
# Nearest to if: when, though, where, thus, since, therefore, before, whether,
# Nearest to all: many, both, various, some, always, certain, identical, most,
# Nearest to at: near, during, johore, in, cvd, angular, virtualization, outside,
# Nearest to state: butt, cdu, cinema, danzig, mention, beti, udf, chrome,
# Nearest to of: regarding, following, in, despite, validate, among, include, behind,
# Nearest to up: off, back, out, down, polls, passenger, forward, rollins,
# Nearest to that: which, what, when, where, how, this, although, whom,
# Nearest to people: children, americans, men, persons, residents, jews, writers, individuals,
# Nearest to see: includes, contains, allows, climatology, wilde, provides, robbie, makes,
# Nearest to use: consist, allow, because, support, hamilcar, substitution, application, usage,
# Nearest to seven: eight, six, four, three, five, nine, zero, one,
# Nearest to as: backstreet, mime, autocephalous, shangri, blica, overtake, beyond, ment,
# Nearest to been: become, fer, fallen, occurred, begun, be, grown, come,
# Nearest to had: has, have, having, was, choctaw, were, gives, showed,
# Nearest to s: whose, est, his, flensburg, isbn, sato, timestamp, hoare,
# Average loss at step 92000: 2.904712
# Average loss at step 94000: 2.886420
# Average loss at step 96000: 2.713725
# Average loss at step 98000: 2.452426
# Average loss at step 100000: 2.710826
# Nearest to this: which, some, joyful, it, macquarie, canoe, depriving, the,
# Nearest to if: when, though, where, before, therefore, today, since, because,
# Nearest to all: every, many, both, certain, various, some, any, identical,
# Nearest to at: near, during, in, outside, attended, bribed, intransitive, rial,
# Nearest to state: states, kingdom, government, national, district, senator, danzig, constructions,
# Nearest to of: represents, in, regarding, savory, mri, validate, among, heightened,
# Nearest to up: off, out, back, down, together, forward, polls, farragut,
# Nearest to that: which, where, when, although, kennings, because, whom, libri,
# Nearest to people: persons, jews, children, men, individuals, speakers, americans, residents,
# Nearest to see: includes, refer, contain, allow, include, contains, called, allows,
# Nearest to use: support, consist, development, usage, study, allow, form, sense,
# Nearest to seven: six, four, five, eight, three, nine, zero, two,
# Nearest to as: backstreet, spectacled, homininae, dora, mime, ably, freeware, autocephalous,
# Nearest to been: become, fallen, grown, fer, begun, occurred, evolved, previously,
# Nearest to had: has, have, having, was, were, includes, wrote, vre,
# Nearest to s: his, whose, her, your, my, autodesk, toffler, siouxsie,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
